-- %%
CREATE OR REPLACE VIEW gold.v_receitaliquida_x_receitabruta AS
SELECT
  mes,
  SUM(faturamento_bruto) AS receita_bruta,
  SUM(receita_liquida) AS receita_liquida
FROM gold.fct_vendas_resumo
GROUP BY mes;
-- Out:
-- Databricks visualization. Run in Databricks to view.
