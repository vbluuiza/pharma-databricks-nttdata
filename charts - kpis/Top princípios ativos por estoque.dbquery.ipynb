-- %%
CREATE OR REPLACE VIEW gold.v_top_principios_ativos_por_estoque AS
SELECT
  nome_principio_ativo,
  estoque_total
FROM gold.fct_estoque_principio_ativo
LIMIT 20;
-- Out:
-- Databricks visualization. Run in Databricks to view.
