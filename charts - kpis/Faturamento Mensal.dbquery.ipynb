-- %%
CREATE OR REPLACE VIEW gold.v_faturamento_mensal AS
SELECT
  mes,
  SUM(faturamento_bruto) AS faturamento_bruto
FROM gold.fct_vendas_resumo
GROUP BY mes
ORDER BY mes;
-- Out:
-- Databricks visualization. Run in Databricks to view.
