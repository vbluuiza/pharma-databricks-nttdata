-- %%
CREATE OR REPLACE VIEW gold.v_prazo_pagamento_mes AS
SELECT
  mes,
  AVG(prazo_medio_dias) AS prazo_medio
FROM gold.fct_vendas_resumo
GROUP BY mes
-- Out:
-- Databricks visualization. Run in Databricks to view.
