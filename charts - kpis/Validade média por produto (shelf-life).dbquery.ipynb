-- %%
CREATE OR REPLACE VIEW gold.v_validade_media_por_produto AS
SELECT
  nome_produto,
  AVG(validade_dias) AS validade_media_dias
FROM gold.fct_producao_lote
GROUP BY nome_produto;
-- Out:
-- Databricks visualization. Run in Databricks to view.
