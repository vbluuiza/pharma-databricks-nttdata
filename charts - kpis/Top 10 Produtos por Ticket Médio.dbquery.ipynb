-- %%
CREATE OR REPLACE VIEW gold.v_top_10_produtos_por_ticket_medio AS
SELECT
  nome_produto,
  AVG(preco_medio_unitario) AS ticket_medio
FROM gold.fct_vendas_resumo
GROUP BY nome_produto
LIMIT 10;
-- Out:
-- Databricks visualization. Run in Databricks to view.
