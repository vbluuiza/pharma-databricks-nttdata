-- %%
CREATE OR REPLACE VIEW gold.v_receita_tipo_cliente AS
SELECT
  tipo_cliente,
  SUM(faturamento_bruto) AS receita
FROM gold.fct_vendas_resumo
GROUP BY tipo_cliente;
-- Out:
-- Databricks visualization. Run in Databricks to view.
