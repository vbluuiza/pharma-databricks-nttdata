-- %%
CREATE OR REPLACE VIEW gold.v_risco_de_validade AS
SELECT
  status_validade,
  SUM(quantidade_fabricada) AS quantidade
FROM gold.fct_producao_lote
GROUP BY status_validade;
-- Out:
-- Databricks visualization. Run in Databricks to view.
