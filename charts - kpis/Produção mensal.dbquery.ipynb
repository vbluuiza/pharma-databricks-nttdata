-- %%
CREATE OR REPLACE VIEW gold.v_producao_mensal AS
SELECT
  date_format(date_trunc('month', data_fabricacao), 'yyyy-MM') AS mes,
  SUM(quantidade_fabricada) AS total_fabricado
FROM gold.fct_producao_lote
GROUP BY date_format(date_trunc('month', data_fabricacao), 'yyyy-MM');
-- Out:
-- Databricks visualization. Run in Databricks to view.
